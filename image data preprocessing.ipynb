# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as image

# %%
x= np.zeros((50,50,3),dtype='uint8')
plt.imshow(x)

# %%
x[:,:]=[255,0,255]
plt.imshow(x)

# %%
 # reading our  image
space=plt.imread(r'C:\Users\alasy\OneDrive\Desktop\machine learning\download (1).jpeg')
print(type(space),space.shape,space.size,space.ndim,sep='\n')
# Out:
# <class 'numpy.ndarray'>
# (183, 275, 3)
# 150975
# 3

# %%
plt.imshow(space)

# %%
# splitting the image with its respective color channels
spaceRed,spaceGreen,spaceBlue=space[:,:,0],space[:,:,1],space[:,:,2]

# %%
plt.imshow(spaceRed)

# %%
# flip
plt.imshow(np.flip(space))

# %%
space1,space2,space3,space4=np.flip(space),np.flip(space,axis=0),np.flip(space,axis=1),np.flip(space,axis=-1)
spacelr,spaceud=np.fliplr(space),np.flipud(space)

# %%
fig, axis = plt.subplots(2, 3)
axis[0, 0].imshow(space1)
axis[0, 1].imshow(space2)
axis[0, 2].imshow(space3)
axis[1, 0].imshow(space4)
axis[1, 1].imshow(spacelr)
axis[1, 2].imshow(spaceud)

# %%
# roll
x=np.random.randint(1,100,(3,2,2))
x
# Out:
# array([[[39, 76],
#         [37, 53]],
#
#        [[67, 78],
#         [92, 30]],
#
#        [[91, 37],
#         [66, 16]]])

# %%
np.roll(x,1,axis=0)
# Out:
# array([[[91, 37],
#         [66, 16]],
#
#        [[39, 76],
#         [37, 53]],
#
#        [[67, 78],
#         [92, 30]]])

# %%
np.roll(x,1,axis=1)
# Out:
# array([[[37, 53],
#         [39, 76]],
#
#        [[92, 30],
#         [67, 78]],
#
#        [[66, 16],
#         [91, 37]]])

# %%
np.roll(x,1,axis=2)
# Out:
# array([[[76, 39],
#         [53, 37]],
#
#        [[78, 67],
#         [30, 92]],
#
#        [[37, 91],
#         [16, 66]]])

# %%
np.roll(x,1,axis=-1)
# Out:
# array([[[76, 39],
#         [53, 37]],
#
#        [[78, 67],
#         [30, 92]],
#
#        [[37, 91],
#         [16, 66]]])

# %%
plt.imshow(np.roll(space,91,axis=0))

# %%
plt.imshow(np.roll(space,1,axis=-1))

# %%
plt.imshow(np.roll(space,137,axis=1))

# %%
## rotate
plt.imshow(np.rot90(space))  # counter clockwise 90

# %%
plt.imshow(np.rot90(space,2))

# %%
plt.imshow(space[0:30,:])
